# %%
import random
import requests
POC1 = ""
POC2 = ""


players = input('Single player or two players? Type 1 or 2 respectively')


if players == "1":
    POC1= input('Enter Pokemon name  or type in "Random" for a random pokemon (Player 1): ').lower()
    print("Choosing random Pokemon")
    
elif players == "2":
    POC2 = input('Enter Pokemon name  or type in "Random" for a random pokemon (Player 2): ').lower()
    print("Choosing random Pokemon")
    
else: 
     POC1 = random.randrange(1,161)
     POC2 = random.randrange(1,161)


response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{POC1}")
response_dict = response.json()
pokemon1 = response_dict


response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{POC2}")
response_dict = response.json()
pokemon2 = response_dict


def battle(pokemon1, pokemon2):
    print(f"A battle has begun between {pokemon1['name']} and {pokemon2['name']}")
   


battle(pokemon1, pokemon2)
# Out:
# Choosing random Pokemon
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 38
#      33 def battle(pokemon1, pokemon2):
#      34     print(f"A battle has begun between {pokemon1['name']} and {pokemon2['name']}")
# ---> 38 battle(pokemon1, pokemon2)
#
# Cell In[48], line 34, in battle(pokemon1, pokemon2)
#      33 def battle(pokemon1, pokemon2):
# ---> 34     print(f"A battle has begun between {pokemon1['name']} and {pokemon2['name']}")
#
# KeyError: 'name'

# %%
import random
import requests

players = input('Single player or two players? Type 1 or 2 respectively')
POC_1 = ""
POC_2 = ""

try:
    POC_1 = input('Enter Pokemon name (Player 1):').lower()
except:
    print("Invalid or empty input, using random Pokemon")
    POC_1= random.randrange(1,161)

if players == "2":
    try:
        POC_2 = input('Enter Pokemon name (Player 2):').lower()
    except:
        print("Invalid or empty input, using random Pokemon")
        POC_2= random.randrange(1,161)
else:
    POC_2 = random.randrange(1,161)

response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{POC_1}")
response_dict = response.json()
pokemon1 = response_dict


response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{POC_2}")
response_dict = response.json()
pokemon2 = response_dict


def battle(pokemon1, pokemon2):
    print(f"A wild battle has begun between {pokemon1['name']} and {pokemon2['name']}")
    # Logic to determine which pokemon is stronger goes here
    
   

battle(pokemon1, pokemon2)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\claud\OneDrive\Desktop\Data 223\.venv\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...

# %%
import random
import requests

players = input('Single player or two players? Type 1 or 2 respectively')
POC_1 = ""   
POC_2 = ""

try:
    POC_1 = input('Enter Pokemon name (Player 1):').lower()
except:
    print("Invalid or empty input, using random Pokemon")
    POC_1= random.randrange(1,161)

if players == "2":
    try:
        POC_2 = input('Enter Pokemon name (Player 2):').lower()
    except:
        print("Invalid or empty input, using random Pokemon")
        POC_2= random.randrange(1,161)
else:
    POC_2 = random.randrange(1,161)

def get_pokemon(name):
    response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{name}")
    if response.status_code != 200:
        print(f"Pokemon '{name}' does not exist, using a random pokemon")
        return None
    else:
        response_dict = response.json()
        pokemon = response_dict
        return pokemon

pokemon1 = get_pokemon(POC_1)
if not pokemon1:
    pokemon1 = get_pokemon(random.randrange(1,161))


pokemon2 = get_pokemon(POC_2)
if not pokemon2:
    pokemon2 = get_pokemon(random.randrange(1,161))


def battle(pokemon1, pokemon2):
    print(f"A wild battle has begun between {pokemon1['name']} and {pokemon2['name']}")
    # Logic to determine which pokemon is stronger goes here
    
   

battle(pokemon1, pokemon2)
# Out:
# A wild battle has begun between ditto and kabutops

# %%
import random
import requests

players = input('Single player or two players? Type 1 or 2 respectively')

POC_1 = input('Enter Pokemon name (Player 1):').lower() #theres always a player 1
POC_2 = '' # initialise player 2
if players == "2":   
    POC_2 = input('Enter Pokemon name (Player 2):').lower()


def get_pokemon(name):  #creating a function for getting pokemon using name
    response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{name}")  
    if response.status_code != 200:   #if not sucessful (if name of pokemon not in the api)
        print(f"Pokemon '{name}' does not exist")
        return None
    else:
        response_dict = response.json()  #enter the data
        pokemon = response_dict
        return pokemon

pokemon1 = get_pokemon(POC_1) #get pokemon from inputted name
if not pokemon1:
    print(f"Using random Pokemon")   #if no pokemon in pokemon 1, use a random pokemon
    pokemon1 = get_pokemon(random.randrange(1,161))


pokemon2 = get_pokemon(POC_2)
if not pokemon2:     
    print(f"Using random Pokemon")
    pokemon2 = get_pokemon(random.randrange(1,161))


def battle(pokemon1, pokemon2):
    print(f"A wild battle has begun between {pokemon1['name']} and {pokemon2['name']}")

# %%
import random
import requests

players = input('Single player or two players? Type 1 for single player and 2 for multiplayer')

POC_1 = input('Enter Pokemon name, or enter "Random" (Player 1):').lower() #theres always a player 1
POC_2 = '' # initialise player 2
if players == "2":   
    POC_2 = input('Enter Pokemon name (Player 2):').lower()


def get_pokemon(name):  #creating a function for getting pokemon using name
    response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{name}")  
    if response.status_code != 200:   #if not sucessful (if name of pokemon not in the api)
        print(f"Pokemon '{name}' does not exist")
        return None
    else:
        response_dict = response.json()  #enter the data
        pokemon = response_dict
        return pokemon

pokemon1 = get_pokemon(POC_1) #get pokemon from inputted name
if not pokemon1:
    print(f"Using random Pokemon")   #if no pokemon in pokemon 1, use a random pokemon
    pokemon1 = get_pokemon(random.randrange(1,161))


pokemon2 = get_pokemon(POC_2)
if not pokemon2:     
    print(f"Using random Pokemon")
    pokemon2 = get_pokemon(random.randrange(1,161))


def battle(pokemon1, pokemon2):
    print(f"A wild battle has begun between {pokemon1['name']} and {pokemon2['name']}")
    
battle(pokemon1, pokemon2)
# Out:
# Pokemon 'e' does not exist
# Using random Pokemon
# Pokemon 'f' does not exist
# Using random Pokemon
# A wild battle has begun between dragonite and flareon

# %%
import random
import requests
total_pokemons = 1015
players = input('Single player or two players? Type 1 for single player and 2 for multiplayer')

POC_1 = input('Enter Pokemon name, or enter "Random" (Player 1):').lower() 
POC_2 = '' 
if players == "2":   
    POC_2 = input('Enter Pokemon name (Player 2):').lower()


def get_pokemon(name):  
    response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{name}")  
    if response.status_code != 200:   
        print(f"Pokemon '{name}' does not exist")
        return None
    else:
        response_dict = response.json()  
        pokemon = response_dict
        return pokemon

pokemon1 = get_pokemon(POC_1) 
if not pokemon1:
    print(f"Using random Pokemon")  
    pokemon1 = get_pokemon(random.randrange(1,total_pokemons))


pokemon2 = get_pokemon(POC_2)
if not pokemon2:     
    print(f"Using random Pokemon")
    pokemon2 = get_pokemon(random.randrange(1,total_pokemons))


def battle(pokemon1, pokemon2):
    print(f"A wild battle has begun between {pokemon1['name']} and {pokemon2['name']}")


battle(pokemon1, pokemon2)
# Out:
# Pokemon 'dww' does not exist
# Using random Pokemon
# Pokemon 'fenifen' does not exist
# Using random Pokemon
# A wild battle has begun between kabutops and mawile

# %%
POC1 = "Aerodactyl"
POC1 = POC1.lower()
response1 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC1))
data1= response1.text
parse_json1 = json.loads(data1)
info1 = parse_json1['types']
#print(info[0].get('type')) #Keys are (['slot', 'type'])
firstdict = info1[0].get('type')
seconddict = info1[1].get('type')
type1 = firstdict.get('name')
type2 = seconddict.get('name')
print(type1,type2)


POC2 = "Blaziken"
POC2 = POC2.lower()
response2 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC2))
data2 = response2.text
parse_json2 = json.loads(data2)
info2 = parse_json2['types']
firstdict = info2[0].get('type')
seconddict = info2[1].get('type')
type1 = firstdict.get('name')
type2 = seconddict.get('name')
print(type1,type2)

# %%
Typelist = ["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Rock", "Ghost", "Dragon"]
Normaldict = {0 : ["Ghost"], 1/2 : ["Rock"], 1: ["Normal" , "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Dragon"] , 2:[]}
Firedict = {0 :[] , 1/2 :["Fire", "Water", "Rock", "Dragon"] , 1:["Normal", "Electric", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Ghost"] , 2:["Grass", "Ice", "Bug"]}
Waterdict = {0 :[] , 1/2 :["Water", "Grass", "Dragon"] , 1:["Normal", "Electric", "Ice", "Fighting", "Poison", "Flying", "Psychic", "Bug", "Ghost"] , 2:["Fire", "Ground", "Rock"]}
Electricdict = {0 :["Ground"] , 1/2 :["Electric", "Grass", "Dragon"] , 1:["Normal", "Fire", "Ice", "Fighting", "Poison", "Psychic", "Bug", "Rock", "Ghost"] , 2:["Water", "Flying"]}
Grassdict = {0 :[] , 1/2 :["Fire", "Grass", "Poison", "Flying", "Bug", "Dragon"] , 1:["Normal", "Electric", "Ice", "Fighting", "Psychic", "Ghost"] , 2:["Water", "Ground", "Rock"]}
Icedict = {0 :[] , 1/2 :["Water", "Ice"] , 1:["Normal", "Fire", "Electric", "Fighting", "Poison","Psychic", "Bug", "Rock", "Ghost" ] , 2:["Grass", "Ground", "Flying", "Dragon"]}
Fightingdict = {0 :["Ghost"] , 1/2 :["Poison","Flying","Psychic","Bug"] , 1:["Fire", "Water", "Electric", "Grass", "Fighting", "Ground", "Dragon"] , 2:["Normal","Ice","Rock"]}
Poisondict = {0 :[] , 1/2 :["Poison","Ground","Rock","Ghost"] , 1:["Normal","Fire", "Water", "Electric", "Ice", "Fighting", "Flying", "Psychic", "Dragon" ] , 2:["Grass","Bug"]}
Grounddict = {0 :["Flying"] , 1/2 :["Grass","Bug"] , 1:["Normal", "Water", "Ice", "Fighting", "Ground", "Psychic", "Ghost", "Dragon"] , 2:["Fire","Electric","Poison","Rock"]}
Flyingdict = {0 :[] , 1/2 :["Electric","Rock"] , 1:["Normal", "Fire", "Water", "Ice", "Poison", "Ground", "Flying", "Psychic", "Ghost", "Dragon"] , 2:["Grass","Fighting","Bug"]}
Psychicdict = {0 :[] , 1/2 :["Psychic"] , 1:["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Ground", "Flying", "Bug", "Rock", "Ghost", "Dragon"] , 2:["Fighting","Poison"]}
Bugdict = {0 :[] , 1/2 :["Fire","Fighting","Flying","Ghost"] , 1:["Normal", "Water", "Electric", "Ice", "Ground", "Bug", "Rock","Dragon"] , 2:["Grass","Psychic", "Poison"]}
Rockdict = {0 :[] , 1/2 :["Fighting","Ground"] , 1:["Normal", "Water", "Electric", "Grass", "Poison", "Psychic", "Rock", "Ghost", "Dragon"] , 2:["Fire","Ice","Flying","Bug"]}
Ghostdict = {0 :["Normal", "Psychic"] , 1/2 :[] , 1:["Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Bug", "Rock", "Dragon"] , 2:["Ghost"]}
Dragondict = {0 :[] , 1/2 :[] , 1:["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Rock", "Ghost"] , 2:["Dragon"]}

# %%
import random
import requests
total_pokemons = 1015
players = input('Single player or two players? Type 1 for single player and 2 for multiplayer')

POC_1 = input('Enter Pokemon name, or enter "Random" (Player 1):').lower() 
POC_2 = '' 
if players == "2":   
    POC_2 = input('Enter Pokemon name (Player 2):').lower()



def get_pokemon(name):  
    response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{name}")  
    if response.status_code != 200:   
        print(f"Pokemon '{name}' does not exist")
        return None
    else:
        response_dict = response.json()  
        pokemon = response_dict
        return pokemon


correct_1 = get_pokemon(POC_1)
input_1 = ""
input_count = 0
input_limit = 3
randomise = False

while input_1 != get_pokemon(POC_1) and not(randomise):
    if input_count < input_limit:
        input_1 = input("Pokemon doesnt exist, try again")
        input_count += 1
    else:
        randomise = True


pokemon1 = get_pokemon(POC_1) 
    if not pokemon1:
        print(f"Using random Pokemon")  
        pokemon1 = get_pokemon(random.randrange(1,total_pokemons))


pokemon2 = get_pokemon(POC_2)
if not pokemon2:     
    print(f"Using random Pokemon")
    pokemon2 = get_pokemon(random.randrange(1,total_pokemons))


def battle(pokemon1, pokemon2):
    print(f"A wild battle has begun between {pokemon1['name']} and {pokemon2['name']}")


battle(pokemon1, pokemon2)
# Out:
# Pokemon 'lu' does not exist
# Pokemon 'lu' does not exist
# Pokemon 'lu' does not exist
# Pokemon 'lu' does not exist
# Pokemon 'lu' does not exist
# Pokemon 'lu' does not exist
# Pokemon 'lu' does not exist
# Using random Pokemon
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 54
#      50 def battle(pokemon1, pokemon2):
#      51     print(f"A wild battle has begun between {pokemon1['name']} and {pokemon2['name']}")
# ---> 54 battle(pokemon1, pokemon2)
#
# Cell In[85], line 51, in battle(pokemon1, pokemon2)
#      50 def battle(pokemon1, pokemon2):
# ---> 51     print(f"A wild battle has begun between {pokemon1['name']} and {pokemon2['name']}")
#
# KeyError: 'name'

# %%
import random
import requests
total_pokemons = 1015
players = input('Single player or two players? Type 1 for single player and 2 for multiplayer')

POC_1 = input('Enter Pokemon name, or enter "Random" (Player 1):').lower() 
POC_2 = random.randrange(1,total_pokemons) 
if players == "2":   
    POC_2 = input('Enter Pokemon name (Player 2):').lower()



def get_pokemon(name):  
    response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{name}")  
    if response.status_code != 200:   
        print(f"Pokemon '{name}' does not exist")
        return None
    else:
        response_dict = response.json()  
        pokemon = response_dict
        return pokemon


pokemon1 = get_pokemon(POC_1)
input_count = 0
input_limit = 3
randomise = False

while pokemon1 is None and not randomise:
    if input_count < input_limit:
        POC_1 = input(f"Pokemon doesnt exist, try again ({input_limit - input_count} tries left)")
        input_count += 1
    else:
        randomise = True
        print(f"Using random Pokemon")  
        pokemon1 = get_pokemon(random.randrange(1,total_pokemons))


pokemon2 = get_pokemon(POC_2)
if not pokemon2:     
    print(f"Using random Pokemon")
    pokemon2 = get_pokemon(random.randrange(1,total_pokemons))


def battle(pokemon1, pokemon2):
    print(f"A wild battle has begun between {pokemon1['name']} and {pokemon2['name']}")


battle(pokemon1, pokemon2)
# Out:
# Pokemon 'dw' does not exist
# Using random Pokemon
# A wild battle has begun between yveltal and mismagius

# %%
import random
import requests
total_pokemons = 1015
players = input('Single player or two players? Type 1 for single player and 2 for multiplayer')

players_selection = ""
input_count = 0
input_limit = 3
default_single_player = False

while (players != "1" or players !="2")  and not default_single_player:
    if input_count < input_limit:
        players = input(f"Invalid response, Type in 1 for single player or 2 for multiplayer ({input_limit - input_count} tries left)")
        input_count += 1
    else:
        default_single_player = True
        print(f"Choosing Single Player...")  
        players != "2"

POC_1 = input('Enter Pokemon name, or enter "Random" (Player 1):').lower() 
POC_2 = random.randrange(1,total_pokemons) 
if players == "2":   
    POC_2 = input('Enter Pokemon name (Player 2):').lower()


def get_pokemon(name):  
    response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{name}")  
    if response.status_code != 200:   
        print(f"Pokemon '{name}' does not exist")
        return None
    else:
        response_dict = response.json()  
        pokemon = response_dict
        return pokemon


pokemon1 = get_pokemon(POC_1)
input_count = 0
input_limit = 3
randomise = False

while pokemon1 is None and not randomise:
    if input_count < input_limit:
        POC_1 = input(f"Pokemon doesnt exist, try again ({input_limit - input_count} tries left)")
        input_count += 1
    else:
        randomise = True
        print(f"Using random Pokemon")  
        pokemon1 = get_pokemon(random.randrange(1,total_pokemons))



pokemon2 = get_pokemon(POC_1)
input_count = 0
input_limit = 3
randomise = False

while pokemon2 is None and not randomise:
    if input_count < input_limit:
        POC_2 = input(f"Pokemon doesnt exist, try again ({input_limit - input_count} tries left)")
        input_count += 1
    else:
        randomise = True
        print(f"Using random Pokemon")  
        pokemon2 = get_pokemon(random.randrange(1,total_pokemons))




def battle(pokemon1, pokemon2):
    print(f"A wild battle has begun between {pokemon1['name']} and {pokemon2['name']}")


battle(pokemon1, pokemon2)
# Out:
# Choosing Single Player...
# Pokemon 'w' does not exist
# Using random Pokemon
# Pokemon 'w' does not exist
# Using random Pokemon
# A wild battle has begun between grookey and genesect

# %%
import random
import requests
total_pokemons = 1015
players = input('Single player or two players? Type 1 for single player and 2 for multiplayer')

single_player = players("1")
multiplayer = players("2")
input_count = 0
input_limit = 3
default_single_player = False

while players is None and not default_single_player:
    if input_count < input_limit:
        players = input(f"Invalid response, Type in 1 for single player or 2 for multiplayer ({input_limit - input_count} tries left)")
        input_count += 1
    else:
        default_single_player = False
        print(f"Choosing Single Player...")  
        players = single_player

POC_1 = input('Enter Pokemon name, or enter "Random" (Player 1):').lower() 
POC_2 = random.randrange(1,total_pokemons) 
if players == "2":   
    POC_2 = input('Enter Pokemon name (Player 2):').lower()


def get_pokemon(name):  
    response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{name}")  
    if response.status_code != 200:   
        print(f"Pokemon '{name}' does not exist")
        return None
    else:
        response_dict = response.json()  
        pokemon = response_dict
        return pokemon


pokemon1 = get_pokemon(POC_1)
input_count = 0
input_limit = 3
randomise = False

while pokemon1 is None and not randomise:
    if input_count < input_limit:
        POC_1 = input(f"Pokemon doesnt exist, try again ({input_limit - input_count} tries left)")
        input_count += 1
    else:
        randomise = True
        print(f"Using random Pokemon")  
        pokemon1 = get_pokemon(random.randrange(1,total_pokemons))



pokemon2 = get_pokemon(POC_1)
input_count = 0
input_limit = 3
randomise = False

while pokemon2 is None and not randomise:
    if input_count < input_limit:
        POC_2 = input(f"Pokemon doesnt exist, try again ({input_limit - input_count} tries left)")
        input_count += 1
    else:
        randomise = True
        print(f"Using random Pokemon")  
        pokemon2 = get_pokemon(random.randrange(1,total_pokemons))




def battle(pokemon1, pokemon2):
    print(f"A wild battle has begun between {pokemon1['name']} and {pokemon2['name']}")


battle(pokemon1, pokemon2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3 total_pokemons = 1015
#       4 players = input('Single player or two players? Type 1 for single player and 2 for multiplayer')
# ----> 6 single_player = players("1")
#       7 multiplayer = players("2")
#       8 input_count = 0
#
# TypeError: 'str' object is not callable

# %%
# API request

response = requests.get('https://pokeapi.co/api/v2/pokemon/')

def selected_number():
    select_number = "Please select number of player: 1 or 2 or random(R)"
    print(select_number)
    selection = input()
 # selection = input()

    if selection=='1':
        print("You are playing single player!")
        print("Choose a Pokemon by name or ID: ")
        select_pokemon = input().lower()
        select_pokemon_request = f"{response.url}{select_pokemon}"
        player1_pokemon= requests.get(select_pokemon_request)

        if player1_pokemon.status_code == 404:
            print("Pokemon not found. Choosing a random Pokemon.")
            random_pokemon = random_select()
            print(f"The randomly chosen Pokemon is {random_pokemon['name']}")
            opponent_pokemon = random_select()
            print(f"Your opponent has selected {opponent_pokemon['name']}")

        else:
            print(f"Player 1, you have selected {player1_pokemon.json()['name']}")
            opponent_pokemon = random_select()
            print(f"Your opponent has selected {opponent_pokemon['name']}")
            return (player1_pokemon, opponent_pokemon)


    elif selection =='2':
        print("You are playing multiplayer!")
        select_pokemon = input().lower()
        select_pokemon_request = f"{response.url}{select_pokemon}"
        player1_pokemon= requests.get(select_pokemon_request)
        print(f"Player 1, you have selected {player1_pokemon}")
        player2_pokemon= requests.get(select_pokemon_request)
        print(f"Player 2, you have selected {player2_pokemon}")
        return (player1_pokemon, player2_pokemon)


    elif selection == 'r' or selection == 'random':
        print("Choosing two random Pokemon.")
        player1_pokemon= random_select()
        print(f"Player 1, you have selected {player1_pokemon['name']}")
        player2_pokemon= random_select()
        print(f"Player 2, you have selected {player2_pokemon['name']}")
        return (player1_pokemon, player2_pokemon)


    else:
        print("No valid entry. Try again.")
        selected_number()

selected_number()


import random

def random_select():
    pokemon_selection_1 = random.randrange(1,161)
    select_pokemon_request = f"{response.url}{pokemon_selection_1}"
    select_pokemon_response = requests.get(select_pokemon_request)
    select_pokemon_data_1 = select_pokemon_response.json()
    return select_pokemon_data_1



# Check if the request was successful

    if response.status_code != 200:
        print("Error: could not retrieve data for random Pokemon")
        return None


random_select()
# Out:
# Please select number of player: 1 or 2 or random(R)
# Choosing two random Pokemon.
# Player 1, you have selected tauros
# Player 2, you have selected sandshrew
# {'abilities': [{'ability': {'name': 'swarm',
#     'url': 'https://pokeapi.co/api/v2/ability/68/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'technician',
#     'url': 'https://pokeapi.co/api/v2/ability/101/'},
#    'is_hidden': False,
#    'slot': 2},
#   {'ability': {'name': 'steadfast',
#     'url': 'https://pokeapi.co/api/v2/ability/80/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 100,
#  'forms': [{'name': 'scyther',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/123/'}],
#  'game_indices': [{'game_index': 26,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 26,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 26,
#    'version': {'name': 'yellow',
# ...

# %%
f"https://pokeapi.co/api/v2/pokemon/{name}"

# %%
response = requests.get('https://pokeapi.co/api/v2/pokemon/')

def selected_number():
    select_number = "Please select number of player: 1 or 2 or random(R)"
    print(select_number)
    selection = input()
 # selection = input()

    if selection=='1':
        print("You are playing single player!")
        print("Choose a Pokemon by name or ID: ")
        select_pokemon = input().lower()
        select_pokemon_request = f"{response.url}{select_pokemon}"
        player1_pokemon= requests.get(select_pokemon_request)

        if player1_pokemon.status_code == 404:
            print("Pokemon not found. Choosing a random Pokemon.")
            random_pokemon = random_select()
            print(f"The randomly chosen Pokemon is {random_pokemon['name']}")
            opponent_pokemon = random_select()
            print(f"Your opponent has selected {opponent_pokemon['name']}")

        else:
            print(f"Player 1, you have selected {player1_pokemon.json()['name']}")
            opponent_pokemon = random_select()
            print(f"Your opponent has selected {opponent_pokemon['name']}")
            return (player1_pokemon, opponent_pokemon)


    elif selection =='2':
        print("You are playing multiplayer!")
        select_pokemon = input().lower()
        select_pokemon_request = f"{response.url}{select_pokemon}"
        player1_pokemon= requests.get(select_pokemon_request)
        print(f"Player 1, you have selected {player1_pokemon}")
        player2_pokemon= requests.get(select_pokemon_request)
        print(f"Player 2, you have selected {player2_pokemon}")
        return (player1_pokemon, player2_pokemon)


    elif selection == 'r' or selection == 'random':
        print("Choosing two random Pokemon.")
        player1_pokemon= random_select()
        print(f"Player 1, you have selected {player1_pokemon['name']}")
        player2_pokemon= random_select()
        print(f"Player 2, you have selected {player2_pokemon['name']}")
        return (player1_pokemon, player2_pokemon)


    else:
        print("No valid entry. Try again.")
        selected_number()

selected_number()


import random

def random_select():
    pokemon_selection_1 = random.randrange(1,161)
    select_pokemon_request = f"{response.url}{pokemon_selection_1}"
    select_pokemon_response = requests.get(select_pokemon_request)
    select_pokemon_data_1 = select_pokemon_response.json()
    return select_pokemon_data_1



# Check if the request was successful

    if response.status_code != 200:
        print("Error: could not retrieve data for random Pokemon")
        return None


random_select()
# Out:
# Please select number of player: 1 or 2 or random(R)
# Choosing two random Pokemon.
# ...

# %%
# API request

response = requests.get('https://pokeapi.co/api/v2/pokemon/')

def selected_number():
    select_number = "Please select number of player: 1 or 2 or random(R)"
    print(select_number)
    selection = input()
 # selection = input()

    if selection=='1':
        print("You are playing single player!")
        print("Choose a Pokemon by name or ID: ")
        select_pokemon = input().lower()
        select_pokemon_request = f"{response.url}{select_pokemon}"
        player1_pokemon= requests.get(select_pokemon_request)

        if player1_pokemon.status_code == 404:
            print("Pokemon not found. Choosing a random Pokemon.")
            random_pokemon = random_select()
            print(f"The randomly chosen Pokemon is {random_pokemon['name']}")
            opponent_pokemon = random_select()
            print(f"Your opponent has selected {opponent_pokemon['name']}")

        else:
            print(f"Player 1, you have selected {player1_pokemon.json()['name']}")
            opponent_pokemon = random_select()
            print(f"Your opponent has selected {opponent_pokemon['name']}")
            return (player1_pokemon, opponent_pokemon)


    elif selection =='2':
        print("You are playing multiplayer!")
        select_pokemon = input().lower()
        select_pokemon_request = f"{response.url}{select_pokemon}"
        player1_pokemon= requests.get(select_pokemon_request)
        print(f"Player 1, you have selected {player1_pokemon}")
        player2_pokemon= requests.get(select_pokemon_request)
        print(f"Player 2, you have selected {player2_pokemon}")
        return (player1_pokemon, player2_pokemon)


    elif selection == 'r' or selection == 'random':
        print("Choosing two random Pokemon.")
        player1_pokemon= random_select()
        print(f"Player 1, you have selected {player1_pokemon['name']}")
        player2_pokemon= random_select()
        print(f"Player 2, you have selected {player2_pokemon['name']}")
        return (player1_pokemon, player2_pokemon)


    else:
        print("No valid entry. Try again.")
        selected_number()

selected_number()


import random 

def random_select(): 

    response = requests.get('https://pokeapi.co/api/v2/pokemon/') 

    if response.status_code != 200: 

        print("Error: could not retrieve data for random Pokemon") 

        return None 

    pokemon_selection_1 = random.randrange(1,161) 

    select_pokemon_request = f"{response.url}{pokemon_selection_1}" 

    select_pokemon_response = requests.get(select_pokemon_request) 

    select_pokemon_data_1 = select_pokemon_response.json() 

    print(select_pokemon_data_1) 

    return select_pokemon_data_1 

random_select()
# Out:
# Please select number of player: 1 or 2 or random(R)
# Choosing two random Pokemon.
# ...

# %%
import random 

def random_select(): 

    response = requests.get('https://pokeapi.co/api/v2/pokemon/') 

    if response.status_code != 200: 

        print("Error: could not retrieve data for random Pokemon") 

        return None 

    pokemon_selection_1 = random.randrange(1,161) 

    select_pokemon_request = f"{response.url}{pokemon_selection_1}" 

    select_pokemon_response = requests.get(select_pokemon_request) 

    select_pokemon_data_1 = select_pokemon_response.json() 

    print(select_pokemon_data_1) 

    return select_pokemon_data_1 

random_select()
# Out:
# {'abilities': [{'ability': {'name': 'levitate', 'url': 'https://pokeapi.co/api/v2/ability/26/'}, 'is_hidden': False, 'slot': 1}], 'base_experience': 62, 'forms': [{'name': 'gastly', 'url': 'https://pokeapi.co/api/v2/pokemon-form/92/'}], 'game_indices': [{'game_index': 25, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 25, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 25, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 92, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 92, 'version': {'name': 'silver', 'url': 'https://pokeapi.co/api/v2/version/5/'}}, {'game_index': 92, 'version': {'name': 'crystal', 'url': 'https://pokeapi.co/api/v2/version/6/'}}, {'game_index': 92, 'version': {'name': 'ruby', 'url': 'https://pokeapi.co/api/v2/version/7/'}}, {'game_index': 92, 'version': {'name': 'sapphire', 'url': 'https:/
# ...

# %%
response = requests.get('https://pokeapi.co/api/v2/pokemon/')

def selected_number():
    select_number = "Please select number of player: 1 or 2 or random(R)"
    print(select_number)
    selection = input()
 # selection = input()

    if selection=='1':
        print("You are playing single player!")
        print("Choose a Pokemon by name or ID: ")
        select_pokemon = input().lower()
        select_pokemon_request = f"{response.url}{select_pokemon}"
        player1_pokemon= requests.get(select_pokemon_request)

        if player1_pokemon.status_code == 404:
            print("Pokemon not found. Choosing a random Pokemon.")
            random_pokemon = random_select()
            print(f"The randomly chosen Pokemon is {random_pokemon['name']}")
            opponent_pokemon = random_select()
            print(f"Your opponent has selected {opponent_pokemon['name']}")

        else:
            print(f"Player 1, you have selected {player1_pokemon.json()['name']}")
            opponent_pokemon = random_select()
            print(f"Your opponent has selected {opponent_pokemon['name']}")
            return (player1_pokemon, opponent_pokemon)


    elif selection =='2':
        print("You are playing multiplayer!")
        select_pokemon = input().lower()
        select_pokemon_request = f"{response.url}{select_pokemon}"
        player1_pokemon= requests.get(select_pokemon_request)
        print(f"Player 1, you have selected {player1_pokemon}")
        player2_pokemon= requests.get(select_pokemon_request)
        print(f"Player 2, you have selected {player2_pokemon}")
        return (player1_pokemon, player2_pokemon)


    elif selection == 'r' or selection == 'random':
        print("Choosing two random Pokemon.")
        player1_pokemon= random_select()
        print(f"Player 1, you have selected {player1_pokemon['name']}")
        player2_pokemon= random_select()
        print(f"Player 2, you have selected {player2_pokemon['name']}")
        return (player1_pokemon, player2_pokemon)


    else:
        print("No valid entry. Try again.")
        selected_number()

selected_number()


import random

def random_select():
    pokemon_selection_1 = random.randrange(1,161)
    select_pokemon_request = f"response = requests.get('https://pokeapi.co/api/v2/pokemon/')

def selected_number():
    select_number = "Please select number of player: 1 or 2 or random(R)"
    print(select_number)
    selection = input()
 # selection = input()

    if selection=='1':
        print("You are playing single player!")
        print("Choose a Pokemon by name or ID: ")
        select_pokemon = input().lower()
        select_pokemon_request = f"{response.url}{select_pokemon}"
        player1_pokemon= requests.get(select_pokemon_request)

        if player1_pokemon.status_code == 404:
            print("Pokemon not found. Choosing a random Pokemon.")
            random_pokemon = random_select()
            print(f"The randomly chosen Pokemon is {random_pokemon['name']}")
            opponent_pokemon = random_select()
            print(f"Your opponent has selected {opponent_pokemon['name']}")

        else:
            print(f"Player 1, you have selected {player1_pokemon.json()['name']}")
            opponent_pokemon = random_select()
            print(f"Your opponent has selected {opponent_pokemon['name']}")
            return (player1_pokemon, opponent_pokemon)


    elif selection =='2':
        print("You are playing multiplayer!")
        select_pokemon = input().lower()
        select_pokemon_request = f"{response.url}{select_pokemon}"
        player1_pokemon= requests.get(select_pokemon_request)
        print(f"Player 1, you have selected {player1_pokemon}")
        player2_pokemon= requests.get(select_pokemon_request)
        print(f"Player 2, you have selected {player2_pokemon}")
        return (player1_pokemon, player2_pokemon)


    elif selection == 'r' or selection == 'random':
        print("Choosing two random Pokemon.")
        player1_pokemon= random_select()
        print(f"Player 1, you have selected {player1_pokemon['name']}")
        player2_pokemon= random_select()
        print(f"Player 2, you have selected {player2_pokemon['name']}")
        return (player1_pokemon, player2_pokemon)


    else:
        print("No valid entry. Try again.")
        selected_number()

selected_number()


import random

def random_select():
    pokemon_selection_1 = random.randrange(1,161)
    select_pokemon_request = f"{response.url}{pokemon_selection_1}"
    select_pokemon_response = requests.get(select_pokemon_request)
    select_pokemon_data_1 = select_pokemon_response.json()
    return select_pokemon_data_1



# Check if the request was successful

    if response.status_code != 200:
        print("Error: could not retrieve data for random Pokemon")
        return None


random_select()

{pokemon_selection_1}"
    select_pokemon_response = requests.get(select_pokemon_request)
    select_pokemon_data_1 = select_pokemon_response.json()
    return select_pokemon_data_1



# Check if the request was successful

    if response.status_code != 200:
        print("Error: could not retrieve data for random Pokemon")
        return None


random_select()

# %%
##Functions we will use
#Random


#Battle multiplier

def battlemultiplier(POC1,POC2):
    # 1st pokemon
    POC1 = POC1.lower()
    response1 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC1))
    data1= response1.text
    parse_json1 = json.loads(data1)
    info1 = parse_json1['types']
    firstdict = info1[0].get('type')
    POC1type1 = firstdict.get('name')
    if len(info1) == 1:
        POC1type2 = "None"
    elif len(info1) == 2:
        seconddict = info1[1].get('type')
        POC1type2 = seconddict.get('name')
    POC1typelist = [POC1type1,POC1type2]


    # 2nd pokemon
    POC2 = POC2.lower()
    response2 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC2))
    data2 = response2.text
    parse_json2 = json.loads(data2)
    info2 = parse_json2['types']
    firstdict = info2[0].get('type') 
    POC2type1 = firstdict.get('name')
    if len(info2) == 1:
        POC2type2 = "None"
    elif len(info2) == 2:
        seconddict = info2[1].get('type')
        POC2type2 = seconddict.get('name')
    POC2typelist = [POC2type1,POC2type2]

    # Multiplier of first pokemon against second pokemon
    multiplier=1
    for x in POC1typelist:
        if x.capitalize() == "Fairy":
            x = "Normal"
        Typedict = Fulldict[x.capitalize()]
        for y in POC2typelist:
            if y.capitalize() == "Fairy":
                y = "Normal"
            for key,value in Typedict.items():
                if y.capitalize() in value:
                    multiplier*=key
    return multiplier

#Outcome message
def battleoutcome(POC1,POC2):
    firstmult = battlemultiplier(POC1,POC2)
    secondmult = battlemultiplier(POC2,POC1)
    if firstmult > secondmult:
        return "Player 1 wins"
    elif firstmult < secondmult:
        return "Player 2 wins"
    else:
        return "It's a draw!"
#Select how many players play and which pokemon they want


print("Single player or multiplayer?")
players="0"
while players!="1" and players!="2":
    players = input("Please input as a number how many players will be playing, 1 or 2?")
if players == "1":
    print("You are playing single player!")
else:
    print("You are playing multiplayer!")

data1 = "Not Found"
while data1 == "Not Found":
    print("PLAYER 1: Choose your pokemon! Type 'Random' for a Random pokemon or type the name of the pokemon you'd like.")
    POC1 = input("PLAYER 1: Input the Pokemon name or 'Random'")
    POC1 = POC1.lower()
    if POC1 == "random":
        POC1 = str(random.randrange(1,151))
    response1 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC1))
    data1= response1.text
parse_json1 = json.loads(data1)
info1 = parse_json1['name'] 
print("Player 1 has selected: " + info1) #First player has selected their pokemon


if players == "2":
    data2 = "Not Found"
    while data2 == "Not Found":
        print("PLAYER 2: Choose your pokemon! Type 'Random' for a Random pokemon or type the name of the pokemon you'd like.")
        POC2 = input("PLAYER 2: Input the Pokemon name or 'Random'")
        POC2 = POC2.lower()
        if POC2 == "random":
            POC2 = str(random.randrange(1,151))
        response2 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC2))
        data2= response2.text

   
else:
    POC2 = str(random.randrange(1,151))
    response2 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC2))
    data2= response2.text


parse_json2 = json.loads(data2)
info2 = parse_json2['name']
print("Player 2 has selected: " + info2) #Second player has selected their pokemon

#Dictionaries that dictate attribute weakness/stengths
Typelist = ["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Rock", "Ghost", "Dragon"]
Normaldict = {0 : ["Ghost"], 1/2 : ["Rock"], 1: ["Normal" , "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Dragon"] , 2:[]}
Firedict = {0 :[] , 1/2 :["Fire", "Water", "Rock", "Dragon"] , 1:["Normal", "Electric", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Ghost"] , 2:["Grass", "Ice", "Bug"]}
Waterdict = {0 :[] , 1/2 :["Water", "Grass", "Dragon"] , 1:["Normal", "Electric", "Ice", "Fighting", "Poison", "Flying", "Psychic", "Bug", "Ghost"] , 2:["Fire", "Ground", "Rock"]}
Electricdict = {0 :["Ground"] , 1/2 :["Electric", "Grass", "Dragon"] , 1:["Normal", "Fire", "Ice", "Fighting", "Poison", "Psychic", "Bug", "Rock", "Ghost"] , 2:["Water", "Flying"]}
Grassdict = {0 :[] , 1/2 :["Fire", "Grass", "Poison", "Flying", "Bug", "Dragon"] , 1:["Normal", "Electric", "Ice", "Fighting", "Psychic", "Ghost"] , 2:["Water", "Ground", "Rock"]}
Icedict = {0 :[] , 1/2 :["Water", "Ice"] , 1:["Normal", "Fire", "Electric", "Fighting", "Poison","Psychic", "Bug", "Rock", "Ghost" ] , 2:["Grass", "Ground", "Flying", "Dragon"]}
Fightingdict = {0 :["Ghost"] , 1/2 :["Poison","Flying","Psychic","Bug"] , 1:["Fire", "Water", "Electric", "Grass", "Fighting", "Ground", "Dragon"] , 2:["Normal","Ice","Rock"]}
Poisondict = {0 :[] , 1/2 :["Poison","Ground","Rock","Ghost"] , 1:["Normal","Fire", "Water", "Electric", "Ice", "Fighting", "Flying", "Psychic", "Dragon" ] , 2:["Grass","Bug"]}
Grounddict = {0 :["Flying"] , 1/2 :["Grass","Bug"] , 1:["Normal", "Water", "Ice", "Fighting", "Ground", "Psychic", "Ghost", "Dragon"] , 2:["Fire","Electric","Poison","Rock"]}
Flyingdict = {0 :[] , 1/2 :["Electric","Rock"] , 1:["Normal", "Fire", "Water", "Ice", "Poison", "Ground", "Flying", "Psychic", "Ghost", "Dragon"] , 2:["Grass","Fighting","Bug"]}
Psychicdict = {0 :[] , 1/2 :["Psychic"] , 1:["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Ground", "Flying", "Bug", "Rock", "Ghost", "Dragon"] , 2:["Fighting","Poison"]}
Bugdict = {0 :[] , 1/2 :["Fire","Fighting","Flying","Ghost"] , 1:["Normal", "Water", "Electric", "Ice", "Ground", "Bug", "Rock","Dragon"] , 2:["Grass","Psychic", "Poison"]}
Rockdict = {0 :[] , 1/2 :["Fighting","Ground"] , 1:["Normal", "Water", "Electric", "Grass", "Poison", "Psychic", "Rock", "Ghost", "Dragon"] , 2:["Fire","Ice","Flying","Bug"]}
Ghostdict = {0 :["Normal", "Psychic"] , 1/2 :[] , 1:["Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Bug", "Rock", "Dragon"] , 2:["Ghost"]}
Dragondict = {0 :[] , 1/2 :[] , 1:["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Rock", "Ghost"] , 2:["Dragon"]}
Nonedict = {1: ["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Rock", "Ghost", "Dragon"]}
Fulldict = {"None" : Nonedict, "Normal" : Normaldict, "Fire" : Firedict, "Water" : Waterdict, "Electric" : Electricdict, "Grass" : Grassdict, "Ice" : Icedict, "Fighting" : Fightingdict, "Poison" : Poisondict, "Ground" : Grounddict, "Flying" : Flyingdict, "Psychic" : Psychicdict, "Bug" : Bugdict, "Rock" : Rockdict, "Ghost" : Ghostdict, "Dragon" :Dragondict}




print(battleoutcome(POC1,POC2)) #GAME OVER!
# Out:
# Single player or multiplayer?
# You are playing single player!
# PLAYER 1: Choose your pokemon! Type 'Random' for a Random pokemon or type the name of the pokemon you'd like.
# PLAYER 1: Choose your pokemon! Type 'Random' for a Random pokemon or type the name of the pokemon you'd like.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 84
#      82     response1 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC1))
#      83     data1= response1.text
# ---> 84 parse_json1 = json.loads(data1)
#      85 info1 = parse_json1['name']
#      86 print("Player 1 has selected: " + info1) #First player has selected their pokemon
#
# NameError: name 'json' is not defined

# %%
##Functions we will use
#Random


#Battle multiplier

def battlemultiplier(POC1,POC2):
    # 1st pokemon
    POC1 = POC1.lower()
    response1 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC1))
    data1= response1.text
    parse_json1 = json.loads(data1)
    info1 = parse_json1['types']
    firstdict = info1[0].get('type')
    POC1type1 = firstdict.get('name')
    if len(info1) == 1:
        POC1type2 = "None"
    elif len(info1) == 2:
        seconddict = info1[1].get('type')
        POC1type2 = seconddict.get('name')
    POC1typelist = [POC1type1,POC1type2]


    # 2nd pokemon
    POC2 = POC2.lower()
    response2 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC2))
    data2 = response2.text
    parse_json2 = json.loads(data2)
    info2 = parse_json2['types']
    firstdict = info2[0].get('type') 
    POC2type1 = firstdict.get('name')
    if len(info2) == 1:
        POC2type2 = "None"
    elif len(info2) == 2:
        seconddict = info2[1].get('type')
        POC2type2 = seconddict.get('name')
    POC2typelist = [POC2type1,POC2type2]

    # Multiplier of first pokemon against second pokemon
    multiplier=1
    for x in POC1typelist:
        if x.capitalize() == "Fairy":
            x = "Normal"
        Typedict = Fulldict[x.capitalize()]
        for y in POC2typelist:
            if y.capitalize() == "Fairy":
                y = "Normal"
            for key,value in Typedict.items():
                if y.capitalize() in value:
                    multiplier*=key
    return multiplier

#Outcome message
def battleoutcome(POC1,POC2):
    firstmult = battlemultiplier(POC1,POC2)
    secondmult = battlemultiplier(POC2,POC1)
    if firstmult > secondmult:
        return "Player 1 wins"
    elif firstmult < secondmult:
        return "Player 2 wins"
    else:
        return "It's a draw!"
#Select how many players play and which pokemon they want


print("Single player or multiplayer?")
players="0"
while players!="1" and players!="2":
    players = input("Please input as a number how many players will be playing, 1 or 2?")
if players == "1":
    print("You are playing single player!")
else:
    print("You are playing multiplayer!")

data1 = "Not Found"
while data1 == "Not Found":
    print("PLAYER 1: Choose your pokemon! Type 'Random' for a Random pokemon or type the name of the pokemon you'd like.")
    POC1 = input("PLAYER 1: Input the Pokemon name or 'Random'")
    POC1 = POC1.lower()
    if POC1 == "random":
        POC1 = str(random.randrange(1,151))
    response1 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC1))
    data1= response1.text
parse_json1 = json.loads(data1)
info1 = parse_json1['name'] 
print("Player 1 has selected: " + info1) #First player has selected their pokemon


if players == "2":
    data2 = "Not Found"
    while data2 == "Not Found":
        print("PLAYER 2: Choose your pokemon! Type 'Random' for a Random pokemon or type the name of the pokemon you'd like.")
        POC2 = input("PLAYER 2: Input the Pokemon name or 'Random'")
        POC2 = POC2.lower()
        if POC2 == "random":
            POC2 = str(random.randrange(1,151))
        response2 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC2))
        data2= response2.text

   
else:
    POC2 = str(random.randrange(1,151))
    response2 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC2))
    data2= response2.text


parse_json2 = json.loads(data2)
info2 = parse_json2['name']
print("Player 2 has selected: " + info2) #Second player has selected their pokemon

#Dictionaries that dictate attribute weakness/stengths
Typelist = ["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Rock", "Ghost", "Dragon"]
Normaldict = {0 : ["Ghost"], 1/2 : ["Rock"], 1: ["Normal" , "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Dragon"] , 2:[]}
Firedict = {0 :[] , 1/2 :["Fire", "Water", "Rock", "Dragon"] , 1:["Normal", "Electric", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Ghost"] , 2:["Grass", "Ice", "Bug"]}
Waterdict = {0 :[] , 1/2 :["Water", "Grass", "Dragon"] , 1:["Normal", "Electric", "Ice", "Fighting", "Poison", "Flying", "Psychic", "Bug", "Ghost"] , 2:["Fire", "Ground", "Rock"]}
Electricdict = {0 :["Ground"] , 1/2 :["Electric", "Grass", "Dragon"] , 1:["Normal", "Fire", "Ice", "Fighting", "Poison", "Psychic", "Bug", "Rock", "Ghost"] , 2:["Water", "Flying"]}
Grassdict = {0 :[] , 1/2 :["Fire", "Grass", "Poison", "Flying", "Bug", "Dragon"] , 1:["Normal", "Electric", "Ice", "Fighting", "Psychic", "Ghost"] , 2:["Water", "Ground", "Rock"]}
Icedict = {0 :[] , 1/2 :["Water", "Ice"] , 1:["Normal", "Fire", "Electric", "Fighting", "Poison","Psychic", "Bug", "Rock", "Ghost" ] , 2:["Grass", "Ground", "Flying", "Dragon"]}
Fightingdict = {0 :["Ghost"] , 1/2 :["Poison","Flying","Psychic","Bug"] , 1:["Fire", "Water", "Electric", "Grass", "Fighting", "Ground", "Dragon"] , 2:["Normal","Ice","Rock"]}
Poisondict = {0 :[] , 1/2 :["Poison","Ground","Rock","Ghost"] , 1:["Normal","Fire", "Water", "Electric", "Ice", "Fighting", "Flying", "Psychic", "Dragon" ] , 2:["Grass","Bug"]}
Grounddict = {0 :["Flying"] , 1/2 :["Grass","Bug"] , 1:["Normal", "Water", "Ice", "Fighting", "Ground", "Psychic", "Ghost", "Dragon"] , 2:["Fire","Electric","Poison","Rock"]}
Flyingdict = {0 :[] , 1/2 :["Electric","Rock"] , 1:["Normal", "Fire", "Water", "Ice", "Poison", "Ground", "Flying", "Psychic", "Ghost", "Dragon"] , 2:["Grass","Fighting","Bug"]}
Psychicdict = {0 :[] , 1/2 :["Psychic"] , 1:["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Ground", "Flying", "Bug", "Rock", "Ghost", "Dragon"] , 2:["Fighting","Poison"]}
Bugdict = {0 :[] , 1/2 :["Fire","Fighting","Flying","Ghost"] , 1:["Normal", "Water", "Electric", "Ice", "Ground", "Bug", "Rock","Dragon"] , 2:["Grass","Psychic", "Poison"]}
Rockdict = {0 :[] , 1/2 :["Fighting","Ground"] , 1:["Normal", "Water", "Electric", "Grass", "Poison", "Psychic", "Rock", "Ghost", "Dragon"] , 2:["Fire","Ice","Flying","Bug"]}
Ghostdict = {0 :["Normal", "Psychic"] , 1/2 :[] , 1:["Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Bug", "Rock", "Dragon"] , 2:["Ghost"]}
Dragondict = {0 :[] , 1/2 :[] , 1:["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Rock", "Ghost"] , 2:["Dragon"]}
Nonedict = {1: ["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Rock", "Ghost", "Dragon"]}
Fulldict = {"None" : Nonedict, "Normal" : Normaldict, "Fire" : Firedict, "Water" : Waterdict, "Electric" : Electricdict, "Grass" : Grassdict, "Ice" : Icedict, "Fighting" : Fightingdict, "Poison" : Poisondict, "Ground" : Grounddict, "Flying" : Flyingdict, "Psychic" : Psychicdict, "Bug" : Bugdict, "Rock" : Rockdict, "Ghost" : Ghostdict, "Dragon" :Dragondict}




print(battleoutcome(POC1,POC2)) #GAME OVER!
# Out:
# Single player or multiplayer?
# You are playing single player!
# PLAYER 1: Choose your pokemon! Type 'Random' for a Random pokemon or type the name of the pokemon you'd like.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 84
#      82     response1 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC1))
#      83     data1= response1.text
# ---> 84 parse_json1 = (json).loads(data1)
#      85 info1 = parse_json1['name']
#      86 print("Player 1 has selected: " + info1) #First player has selected their pokemon
#
# NameError: name 'json' is not defined

# %%
##Functions we will use
#Random
#Battle multiplier

def battlemultiplier(POC1,POC2):
    # 1st pokemon
    POC1 = POC1.lower()
    response1 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC1))
    data1= response1.text
    parse_json1 = json.loads(data1)
    info1 = parse_json1['types']
    firstdict = info1[0].get('type')
    POC1type1 = firstdict.get('name')
    if len(info1) == 1:
        POC1type2 = "None"
    elif len(info1) == 2:
        seconddict = info1[1].get('type')
        POC1type2 = seconddict.get('name')
    POC1typelist = [POC1type1,POC1type2]


    # 2nd pokemon
    POC2 = POC2.lower()
    response2 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC2))
    data2 = response2.text
    parse_json2 = json.loads(data2)
    info2 = parse_json2['types']
    firstdict = info2[0].get('type') 
    POC2type1 = firstdict.get('name')
    if len(info2) == 1:
        POC2type2 = "None"
    elif len(info2) == 2:
        seconddict = info2[1].get('type')
        POC2type2 = seconddict.get('name')
    POC2typelist = [POC2type1,POC2type2]

    # Multiplier of first pokemon against second pokemon
    multiplier=1
    for x in POC1typelist:
        if x.capitalize() == "Fairy":
            x = "Normal"
        Typedict = Fulldict[x.capitalize()]
        for y in POC2typelist:
            if y.capitalize() == "Fairy":
                y = "Normal"
            for key,value in Typedict.items():
                if y.capitalize() in value:
                    multiplier*=key
    return multiplier

#Outcome message
def battleoutcome(POC1,POC2):
    firstmult = battlemultiplier(POC1,POC2)
    secondmult = battlemultiplier(POC2,POC1)
    if firstmult > secondmult:
        return "Player 1 wins"
    elif firstmult < secondmult:
        return "Player 2 wins"
    else:
        return "It's a draw!"
#Select how many players play and which pokemon they want


print("Single player or multiplayer?")
players="0"
while players!="1" and players!="2":
    players = input("Please input as a number how many players will be playing, 1 or 2?")
if players == "1":
    print("You are playing single player!")
else:
    print("You are playing multiplayer!")

data1 = "Not Found"
while data1 == "Not Found":
    print("PLAYER 1: Choose your pokemon! Type 'Random' for a Random pokemon or type the name of the pokemon you'd like.")
    POC1 = input("PLAYER 1: Input the Pokemon name or 'Random'")
    POC1 = POC1.lower()
    if POC1 == "random":
        POC1 = str(random.randrange(1,151))
    response1 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC1))
    data1= response1.text
parse_json1 = json.loads(data1)
info1 = parse_json1['name'] 
print("Player 1 has selected: " + info1) #First player has selected their pokemon


if players == "2":
    data2 = "Not Found"
    while data2 == "Not Found":
        print("PLAYER 2: Choose your pokemon! Type 'Random' for a Random pokemon or type the name of the pokemon you'd like.")
        POC2 = input("PLAYER 2: Input the Pokemon name or 'Random'")
        POC2 = POC2.lower()
        if POC2 == "random":
            POC2 = str(random.randrange(1,151))
        response2 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC2))
        data2= response2.text

   
else:
    POC2 = str(random.randrange(1,151))
    response2 = requests.get('https://pokeapi.co/api/v2/pokemon/'+str(POC2))
    data2= response2.text

import json


parse_json2 = json.loads(data2)
info2 = parse_json2['name']
print("Player 2 has selected: " + info2) #Second player has selected their pokemon

#Dictionaries that dictate attribute weakness/stengths
Typelist = ["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Rock", "Ghost", "Dragon"]
Normaldict = {0 : ["Ghost"], 1/2 : ["Rock"], 1: ["Normal" , "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Dragon"] , 2:[]}
Firedict = {0 :[] , 1/2 :["Fire", "Water", "Rock", "Dragon"] , 1:["Normal", "Electric", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Ghost"] , 2:["Grass", "Ice", "Bug"]}
Waterdict = {0 :[] , 1/2 :["Water", "Grass", "Dragon"] , 1:["Normal", "Electric", "Ice", "Fighting", "Poison", "Flying", "Psychic", "Bug", "Ghost"] , 2:["Fire", "Ground", "Rock"]}
Electricdict = {0 :["Ground"] , 1/2 :["Electric", "Grass", "Dragon"] , 1:["Normal", "Fire", "Ice", "Fighting", "Poison", "Psychic", "Bug", "Rock", "Ghost"] , 2:["Water", "Flying"]}
Grassdict = {0 :[] , 1/2 :["Fire", "Grass", "Poison", "Flying", "Bug", "Dragon"] , 1:["Normal", "Electric", "Ice", "Fighting", "Psychic", "Ghost"] , 2:["Water", "Ground", "Rock"]}
Icedict = {0 :[] , 1/2 :["Water", "Ice"] , 1:["Normal", "Fire", "Electric", "Fighting", "Poison","Psychic", "Bug", "Rock", "Ghost" ] , 2:["Grass", "Ground", "Flying", "Dragon"]}
Fightingdict = {0 :["Ghost"] , 1/2 :["Poison","Flying","Psychic","Bug"] , 1:["Fire", "Water", "Electric", "Grass", "Fighting", "Ground", "Dragon"] , 2:["Normal","Ice","Rock"]}
Poisondict = {0 :[] , 1/2 :["Poison","Ground","Rock","Ghost"] , 1:["Normal","Fire", "Water", "Electric", "Ice", "Fighting", "Flying", "Psychic", "Dragon" ] , 2:["Grass","Bug"]}
Grounddict = {0 :["Flying"] , 1/2 :["Grass","Bug"] , 1:["Normal", "Water", "Ice", "Fighting", "Ground", "Psychic", "Ghost", "Dragon"] , 2:["Fire","Electric","Poison","Rock"]}
Flyingdict = {0 :[] , 1/2 :["Electric","Rock"] , 1:["Normal", "Fire", "Water", "Ice", "Poison", "Ground", "Flying", "Psychic", "Ghost", "Dragon"] , 2:["Grass","Fighting","Bug"]}
Psychicdict = {0 :[] , 1/2 :["Psychic"] , 1:["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Ground", "Flying", "Bug", "Rock", "Ghost", "Dragon"] , 2:["Fighting","Poison"]}
Bugdict = {0 :[] , 1/2 :["Fire","Fighting","Flying","Ghost"] , 1:["Normal", "Water", "Electric", "Ice", "Ground", "Bug", "Rock","Dragon"] , 2:["Grass","Psychic", "Poison"]}
Rockdict = {0 :[] , 1/2 :["Fighting","Ground"] , 1:["Normal", "Water", "Electric", "Grass", "Poison", "Psychic", "Rock", "Ghost", "Dragon"] , 2:["Fire","Ice","Flying","Bug"]}
Ghostdict = {0 :["Normal", "Psychic"] , 1/2 :[] , 1:["Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Bug", "Rock", "Dragon"] , 2:["Ghost"]}
Dragondict = {0 :[] , 1/2 :[] , 1:["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Rock", "Ghost"] , 2:["Dragon"]}
Nonedict = {1: ["Normal", "Fire", "Water", "Electric", "Grass", "Ice", "Fighting", "Poison", "Ground", "Flying", "Psychic", "Bug", "Rock", "Ghost", "Dragon"]}
Fulldict = {"None" : Nonedict, "Normal" : Normaldict, "Fire" : Firedict, "Water" : Waterdict, "Electric" : Electricdict, "Grass" : Grassdict, "Ice" : Icedict, "Fighting" : Fightingdict, "Poison" : Poisondict, "Ground" : Grounddict, "Flying" : Flyingdict, "Psychic" : Psychicdict, "Bug" : Bugdict, "Rock" : Rockdict, "Ghost" : Ghostdict, "Dragon" :Dragondict}




print(battleoutcome(POC1,POC2)) #GAME OVER!
# Out:
# Single player or multiplayer?
# You are playing multiplayer!
# PLAYER 1: Choose your pokemon! Type 'Random' for a Random pokemon or type the name of the pokemon you'd like.
# Player 1 has selected: arcanine
# PLAYER 2: Choose your pokemon! Type 'Random' for a Random pokemon or type the name of the pokemon you'd like.
# Player 2 has selected: machoke
# It's a draw!
